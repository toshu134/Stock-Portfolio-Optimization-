# %%
import pandas as pd 
import numpy as np
file = "C://Users//Arnav Singh//OneDrive//Desktop//12//stock_data.csv" 
df = pd.read_csv(file)

# %%
df.head
df.columns
# Out:
# Index(['Date', 'RELIANCE.NS', 'TCS.NS', 'HDFCBANK.NS', 'BHARTIARTL.NS',
#        'ICICIBANK.NS', 'INFY.NS', 'HINDUNILVR.NS', 'WIPRO.NS', 'JSWSTEEL.NS',
#        'SBILIFE.NS', 'BAJAJFINSV.NS', 'TATACONSUM.NS', 'HCLTECH.NS',
#        'SUNPHARMA.NS', 'M&M.NS', 'LT.NS', 'ASIANPAINT.NS', 'NESTLEIND.NS',
#        'MARUTI.NS', 'TATAMOTORS.NS', 'BAJAJ-AUTO.NS', 'ULTRACEMCO.NS',
#        'KOTAKBANK.NS', 'HDFCLIFE.NS', 'INDUSINDBK.NS', 'TECHM.NS',
#        'INFRATEL.NS', 'TITAN.NS', 'SBIN.NS', 'AXISBANK.NS', 'ADANIPORTS.NS',
#        'NTPC.NS', 'COALINDIA.NS', 'POWERGRID.NS', 'BPCL.NS', 'ONGC.NS',
#        'TATASTEEL.NS', 'HINDALCO.NS', 'APOLLOTYRE.NS', 'GRASIM.NS',
#        'M&MFIN.NS', 'SHREECEM.NS', 'DABUR.NS', 'GODREJCP.NS', 'EICHERMOT.NS',
#        'TATAPOWER.NS', 'ZEEL.NS', 'LTTS.NS', 'BOSCHLTD.NS', 'TATACHEM.NS'],
#       dtype='object')

# %%
df['Date']
# Out:
# 0       01-01-2020
# 1       02-01-2020
# 2       03-01-2020
# 3       06-01-2020
# 4       07-01-2020
#            ...
# 1232    23-12-2024
# 1233    24-12-2024
# 1234    26-12-2024
# 1235    27-12-2024
# 1236    30-12-2024
# Name: Date, Length: 1237, dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
df.set_index('Date', inplace=True)

# %%
df.head
list = ['HDFCLIFE.NS', 'INDUSINDBK.NS', 'TECHM.NS']

# %%
df[list]
# Out:
#             HDFCLIFE.NS  INDUSINDBK.NS  TECHM.NS
# Date
# 2020-01-01       613.77        1433.39    650.00
# 2020-01-02       626.42        1476.56    653.37
# 2020-01-03       622.91        1476.42    661.09
# 2020-01-06       611.90        1419.01    657.08
# 2020-01-07       622.17        1411.52    662.80
# ...                 ...            ...       ...
# 2024-12-23       622.55         945.70   1712.40
# 2024-12-24       622.50         935.30   1704.90
# 2024-12-26       626.40         931.95   1698.70
# 2024-12-27       621.90         953.40   1711.65
# 2024-12-30       617.40         963.50   1740.85
#
# [1237 rows x 3 columns]

# %%
df.pct_change().iloc[1:]
# Out:
#             RELIANCE.NS    TCS.NS  HDFCBANK.NS  BHARTIARTL.NS  ICICIBANK.NS  \
# Date
# 2020-01-02     0.017025 -0.004587     0.006371       0.004188      0.007189
# 2020-01-03     0.001206  0.019926    -0.014256      -0.000228     -0.003253
# 2020-01-06    -0.023199 -0.000090    -0.021640      -0.011968     -0.024401
# 2024-12-23     -0.002992  0.003916 -0.017283    -0.001501     0.005249
# 2024-12-24     -0.001250  0.004139 -0.003267    -0.003470     0.032246
# 2024-12-26      0.012268 -0.010227 -0.013003    -0.006253    -0.009320
# 2024-12-27     -0.013109 -0.001121  0.005195    -0.002938    -0.010684
# 2024-12-30     -0.023183 -0.020929  0.013256    -0.008561    -0.013905
#
# [1236 rows x 50 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1237 entries, 2020-01-01 to 2024-12-30
# Data columns (total 50 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RELIANCE.NS    1237 non-null   float64
#  1   TCS.NS         1237 non-null   float64
#  2   HDFCBANK.NS    1237 non-null   float64
#  3   BHARTIARTL.NS  1237 non-null   float64
#  4   ICICIBANK.NS   1237 non-null   float64
#  5   INFY.NS        1237 non-null   float64
#  6   HINDUNILVR.NS  1237 non-null   float64
#  7   WIPRO.NS       1237 non-null   float64
#  8   JSWSTEEL.NS    1237 non-null   float64
#  9   SBILIFE.NS     1237 non-null   float64
#  10  BAJAJFINSV.NS  1237 non-null   float64
#  11  TATACONSUM.NS  1237 non-null   float64
#  12  HCLTECH.NS     1237 non-null   float64
#  13  SUNPHARMA.NS   1237 non-null   float64
#  14  M&M.NS         1237 non-null   float64
#  15  LT.NS          1237 non-null   float64
#  16  ASIANPAINT.NS  1237 non-null   float64
#  17  NESTLEIND.NS   1237 non-null   float64
#  18  MARUTI.NS      1237 non-null   float64
#  19  TATAMOTORS.NS  1237 non-null   float64
#  20  BAJAJ-AUTO.NS  1237 non-null   float64
#  21  ULTRACEMCO.NS  1237 non-null   float64
#  22  KOTAKBANK.NS   1237 non-null   float64
#  23  HDFCLIFE.NS    1237 non-null   float64
#  24  INDUSINDBK.NS  1237 non-null   float64
#  25  TECHM.NS       1237 non-null   float64
#  26  INFRATEL.NS    0 non-null      float64
#  27  TITAN.NS       1237 non-null   float64
#  28  SBIN.NS        1237 non-null   float64
#  29  AXISBANK.NS    1237 non-null   float64
#  30  ADANIPORTS.NS  1237 non-null   float64
#  31  NTPC.NS        1237 non-null   float64
#  32  COALINDIA.NS   1237 non-null   float64
#  33  POWERGRID.NS   1237 non-null   float64
#  34  BPCL.NS        1237 non-null   float64
#  35  ONGC.NS        1237 non-null   float64
#  36  TATASTEEL.NS   1237 non-null   float64
#  37  HINDALCO.NS    1237 non-null   float64
#  38  APOLLOTYRE.NS  1237 non-null   float64
#  39  GRASIM.NS      1237 non-null   float64
#  40  M&MFIN.NS      1237 non-null   float64
#  41  SHREECEM.NS    1237 non-null   float64
#  42  DABUR.NS       1237 non-null   float64
#  43  GODREJCP.NS    1237 non-null   float64
#  44  EICHERMOT.NS   1237 non-null   float64
#  45  TATAPOWER.NS   1237 non-null   float64
#  46  ZEEL.NS        1237 non-null   float64
#  47  LTTS.NS        1237 non-null   float64
#  48  BOSCHLTD.NS    1237 non-null   float64
#  49  TATACHEM.NS    1237 non-null   float64
# dtypes: float64(50)
# memory usage: 492.9 KB
